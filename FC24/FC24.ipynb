# %%
import pandas as pd

# %%
jogadores = pd.read_csv('FC24/Players.csv')
jogadores

# %%
jogadores.columns

# %%
jogadores.loc[(jogadores['fifa_version'] == 24.0)]

# %%
jogadores.head(30)

# %%
jogadores.loc[(jogadores['fifa_version'] == 24.0) & (jogadores['potential'] >= 90)].sort_values(by=['potential', 'value_eur'], ascending=False).head(35)
# Out:
#      player_id                                         player_url  \
# 1       239085               /player/239085/erling-haaland/240002
# 0       231747                /player/231747/kylian-mbappe/240002
# 8       238794  /player/238794/vinicius-jose-de-oliveira-junio...
# 35      256790                /player/256790/jamal-musiala/240002
# 17      239053            /player/239053/federico-valverde/240002
# 36      247635        /player/247635/khvicha-kvaratskhelia/240002
# 37      251854         /player/251854/pedro-gonzalez-lopez/240002
# 18      232293               /player/232293/victor-osimhen/240002
# 2       192985              /player/192985/kevin-de-bruyne/240002
# 38      241721     /player/241721/rafael-da-conceicao-leao/240002
# 39      252371              /player/252371/jude-bellingham/240002
# 40      253163                /player/253163/ronald-araujo/240002
# 61      243812        /player/243812/rodrygo-silva-de-goes/240002
# ...
